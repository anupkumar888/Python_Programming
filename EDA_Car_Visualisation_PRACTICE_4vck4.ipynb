# %% [markdown]
# <a href="https://colab.research.google.com/github/anupkumar888/Python_Programming/blob/Python-programming/EDA_Car_Visualisation_PRACTICE_4vck4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv(r"/content/drive/MyDrive/PYTHON PROGRAMMING/Colab Notebooks/PANDAS EDA/auto_car.csv")

# %%
print(df.head())
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns=headers

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# Length: 204, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 199      False              False  False      False       False         False
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["symboling"]
# Out:
# 0      3
# 1      1
# 2      2
# 3      2
# 4      2
#       ..
# 199   -1
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# Name: symboling, Length: 204, dtype: int64

# %%
df["normalized-losses"]
# Out:
# 0        ?
# 1        ?
# 2      164
# 3      164
# 4        ?
#       ...
# 199     95
# 200     95
# 201     95
# 202     95
# 203     95
# Name: normalized-losses, Length: 204, dtype: object

# %%
import numpy as np
df.replace("?",np.nan,inplace=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
missing_data=df.isnull()

missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
# 5      False              False  False      False       False         False
# 6      False               True  False      False       False         False
# 7      False              False  False      False       False         False
# 8      False               True  False      False       False         False
# 9      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %%
missing_data.sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df["normalized-losses"].dtype
# Out:
# dtype('O')

# %%
avg_norloss=df['normalized-losses'].astype("float").mean()

print(avg_norloss)
# Out:
# 122.0

# %%
df["normalized-losses"].replace(np.NAN,avg_norloss,inplace=True)

# %%
df["normalized-losses"]
# Out:
# 0      122.0
# 1      122.0
# 2        164
# 3        164
# 4      122.0
#        ...
# 199       95
# 200       95
# 201       95
# 202       95
# 203       95
# Name: normalized-losses, Length: 204, dtype: object

# %%
missing_data.sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df["normalized-losses"].value_counts()
# Out:
# 122.0    40
# 161      11
# 91        8
# 150       7
# 134       6
# 128       6
# 104       6
# 85        5
# 94        5
# 65        5
# 102       5
# 74        5
# 168       5
# 103       5
# 95        5
# 106       4
# 93        4
# 118       4
# 148       4
# 122       4
# 83        3
# 125       3
# 154       3
# 115       3
# 137       3
# 101       3
# 119       2
# 87        2
# 89        2
# 192       2
# 197       2
# 158       2
# 81        2
# 188       2
# 194       2
# 153       2
# 129       2
# 108       2
# 110       2
# 164       2
# 145       2
# 113       2
# 256       1
# 107       1
# 90        1
# 231       1
# 142       1
# 121       1
# 78        1
# 98        1
# 186       1
# 77        1
# Name: normalized-losses, dtype: int64

# %%
df["num-of-doors"]
# Out:
# 0       two
# 1       two
# 2      four
# 3      four
# 4       two
#        ...
# 199    four
# 200    four
# 201    four
# 202    four
# 203    four
# Name: num-of-doors, Length: 204, dtype: object

# %%
df["num-of-doors"].value_counts()
# Out:
# four    114
# two      88
# Name: num-of-doors, dtype: int64

# %%
df["num-of-doors"].replace(np.nan,"four",inplace=True)

# %%
df_doors=df["num-of-doors"].isnull()
df_doors.sum()
# Out:
# 0

# %%
avg_bore=df["bore"].astype("float").mean(axis=0)
print("Average of bore:",avg_bore)
# Out:
# Average of bore: 3.3290499999999996

# %%
df["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
df["stroke"]
# Out:
# 0      2.68
# 1      3.47
# 2      3.40
# 3      3.40
# 4      3.40
#        ...
# 199    3.15
# 200    3.15
# 201    2.87
# 202    3.40
# 203    3.15
# Name: stroke, Length: 204, dtype: object

# %%
avg_stroke=df["stroke"].astype("float").mean(axis=0)
print("Average of stroke:",avg_stroke)
# Out:
# Average of stroke: 3.2582999999999993

# %%
df["stroke"].replace(np.nan,avg_stroke,inplace=True)

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)

df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# Average horsepower: 104.22277227722772

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df_rpm=df['peak-rpm'].isnull()
df_rpm.sum()
# Out:
# 2

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)

df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)
# Out:
# Average peak rpm: 5125.990099009901

# %%
missing_df=df.isnull()

missing_df.sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.shape
# Out:
# (204, 26)

# %%
df["price"].dtype
# Out:
# dtype('O')

# %%
df.dropna(subset=["price"],axis=0,inplace=True)

# %%
df.shape
# Out:
# (200, 26)

# %%
missing_df=df.isnull()
missing_df.sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ## All missing values are ***handled***

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          1             122.0  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2             122.0         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df["price"]=df["price"].astype("float")

df[["bore",'stroke']]=df[["bore",'stroke']].astype("float")

df["normalized-losses"]=df["normalized-losses"].astype("int")

df["peak-rpm"]=df["peak-rpm"].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Normalization

# %%
df["normalized-losses"]=df["normalized-losses"]*0.9

# %%
df["normalized-losses"].head()
# Out:
# 0    109.8
# 1    109.8
# 2    147.6
# 3    147.6
# 4    109.8
# Name: normalized-losses, dtype: float64

# %%
df["length"].head()
# Out:
# 0    168.8
# 1    171.2
# 2    176.6
# 3    176.6
# 4    177.3
# Name: length, dtype: float64

# %%
df["length"].max()
# Out:
# 208.1

# %%
df["length"]=df["length"]/df["length"].max()

# %%
df['length']
# Out:
# 0      0.811148
# 1      0.822681
# 2      0.848630
# 3      0.848630
# 4      0.851994
#          ...
# 199    0.907256
# 200    0.907256
# 201    0.907256
# 202    0.907256
# 203    0.907256
# Name: length, Length: 200, dtype: float64

# %% [markdown]
# ## Visualization

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              109.8  alfa-romero       gas        std
# 1          1              109.8  alfa-romero       gas        std
# 2          2              147.6         audi       gas        std
# 3          2              147.6         audi       gas        std
# 4          2              109.8         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df["symboling"].value_counts()
# Out:
#  0    65
#  1    52
#  2    32
#  3    26
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
plt.hist(df["symboling"])
# Out:
# (array([ 3.,  0., 22.,  0., 65.,  0., 52.,  0., 32., 26.]),
#  array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ]),
#  <a list of 10 Patch objects>)

# %%
sns.histplot(df["symboling"])

# %%
sns.distplot(df["symboling"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(df["symboling"])

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.469772   -0.529145 -0.364511
# normalized-losses   0.469772           1.000000   -0.057068  0.019433
# wheel-base         -0.529145          -0.057068    1.000000  0.879005
# length             -0.364511           0.019433    0.879005  1.000000
# width              -0.237262           0.086961    0.814593  0.857271
# height             -0.542261          -0.377664    0.583789  0.492955
# curb-weight        -0.234743           0.099404    0.787584  0.881058
# engine-size        -0.112069           0.112362    0.576779  0.685531
# bore               -0.145790          -0.029929    0.501576  0.610847
# stroke              0.008072           0.055673    0.144733  0.120929
# compression-ratio  -0.181073          -0.114738    0.249689  0.159203
# peak-rpm            0.284033           0.239580   -0.365045 -0.286688
# ...

# %%
df[["bore","stroke","compression-ratio"]].corr()
# Out:
#                        bore    stroke  compression-ratio
# bore               1.000000 -0.051087           0.002034
# stroke            -0.051087  1.000000           0.186780
# compression-ratio  0.002034  0.186780           1.000000

# %%
import seaborn as sns

# Engine size as potential predictiion variable of price
sns.regplot(df["engine-size"],df["price"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df[["engine-size", "price"]]
# Out:
#      engine-size    price
# 0            130  16500.0
# 1            152  16500.0
# 2            109  13950.0
# 3            136  17450.0
# 4            136  15250.0
# ..           ...      ...
# 199          141  16845.0
# 200          141  19045.0
# 201          173  21485.0
# 202          145  22470.0
# 203          141  22625.0
#
# [200 rows x 2 columns]

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872337
# price           0.872337  1.000000

# %%
sns.regplot(x="highway-mpg",y="price",data=df)

# %%
df[["highway-mpg", "price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.705115
# price          -0.705115  1.000000

# %%
df["body-style"].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     5
# Name: body-style, dtype: int64

# %%
sns.boxplot(x="body-style",y="price", data=df)

# %%
sns.boxplot(df["body-style"],df["price"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(x="body-style",y="price", data=df,ci=False)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              109.8  alfa-romero       gas        std
# 1          1              109.8  alfa-romero       gas        std
# 2          2              147.6         audi       gas        std
# 3          2              147.6         audi       gas        std
# 4          2              109.8         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df["fuel-type"].value_counts()
# Out:
# gas       180
# diesel     20
# Name: fuel-type, dtype: int64

# %%
sns.barplot(x="body-style",y="price",hue="fuel-type",data=df,ci=False)

# %%
sns.barplot(x="body-style",y="price",hue="fuel-type",data=df,ci=True)

# %%
sns.boxplot(x="body-style",y="price",hue="fuel-type",data=df)

# %%
plt.pie(df["symboling"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe6fea96d50>,
# ...
#  [Text(1.0982275578438683, 0.062419798079561724, ''),
#   Text(1.090361553208201, 0.14529860042477985, ''),
#   Text(1.0803596331335743, 0.20693734098873742, ''),
#   Text(1.061615121299273, 0.28805092297843765, ''),
#   Text(1.0367897746421375, 0.36751457548987904, ''),
#   Text(1.0142644696448682, 0.42575531190581123, ''),
#   Text(0.9974267985346326, 0.46383163062145066, ''),
#   Text(0.9791603232498136, 0.5012435150436569, ''),
#   Text(0.9491393923114004, 0.5559985737056757, ''),
#   Text(0.9274197695451499, 0.5915171773134077, ''),
#   Text(0.9274197695451499, 0.5915171773134077, ''),
#   Text(0.9274197695451499, 0.5915171773134077, ''),
#   Text(0.9160597437893907, 0.6089618590753579, ''),
#   Text(0.9043716269915184, 0.6261884383256481, ''),
#   Text(0.9043716269915184, 0.6261884383256481, ''),
#   Text(0.9043716269915184, 0.6261884383256481, ''),
#   Text(0.8800279808902399, 0.6599626904986734, ''),
# ...

# %%
plt.pie(df["price"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe6fe71d8d0>,
# ...
#  [Text(1.0997881471969333, 0.02158775776075251, ''),
#   Text(1.0980938143585315, 0.0647300151979849, ''),
#   Text(1.0950296169438203, 0.10445160609521632, ''),
#   Text(1.0903655771874894, 0.14526840015844275, ''),
#   Text(1.0838919130845506, 0.1875588460987989, ''),
#   Text(1.075707576512911, 0.2298982597426953, ''),
#   Text(1.0646729820188947, 0.27653470190736384, ''),
#   Text(1.0492232406743647, 0.330349195895471, ''),
#   Text(1.032186085972666, 0.3802523950278663, ''),
#   Text(1.0162911444990637, 0.420894653818249, ''),
#   Text(0.9962932486063286, 0.4662614746914531, ''),
#   Text(0.9717202634358242, 0.5155188935705584, ''),
#   Text(0.9422956590146555, 0.5675199476689222, ''),
#   Text(0.9029354531309193, 0.6282575646017018, ''),
#   Text(0.8458233212510301, 0.7032658880024516, ''),
#   Text(0.776849564044537, 0.7787841516388305, ''),
#   Text(0.7369596209674057, 0.8166336492354315, ''),
# ...
